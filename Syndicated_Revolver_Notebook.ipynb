# %% [markdown]
# # Syndicated Revolver Notebook

# %% [markdown]
# ![Cliffs?](https://imgur.com/ixZxzkF.jpg)

# %% [markdown]
# [Play with it here](https://amoebaquant.com/)

# %% [markdown]
# form and test meaningful hypotheses for a dataset
# clean a dataset using common Python libraries
# identify types of variables in a dataset
# characterize the distributions and relationships of variables in a dataset
# generate appropriate visualizations for a dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Importing data

# %%
from sklearn.model_selection import train_test_split
train, test = train_test_split(pd.read_csv('https://raw.githubusercontent.com/pierretd/investor-classifier/master/data/fake_data%20-%20investor_data.csv'), random_state=0)
data = train.append(test)

# %%
print('Train has {} rows and {} columns.'.format(train.shape[0], train.shape[1]))
# Out:
# Train has 5424 rows and 14 columns.

# %% [markdown]
# To know the total of columns

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5424 entries, 3508 to 2732
# Data columns (total 14 columns):
# investor          5424 non-null object
# commit            5424 non-null object
# deal_size         5424 non-null int64
# invite            5424 non-null int64
# rating            5424 non-null int64
# int_rate          5424 non-null object
# covenants         5424 non-null int64
# total_fees        5424 non-null int64
# fee_share         5424 non-null float64
# prior_tier        5424 non-null object
# invite_tier       5424 non-null object
# tier_change       5424 non-null object
# fee_percent       5424 non-null float64
# invite_percent    5424 non-null float64
# dtypes: float64(3), int64(5), object(6)
# memory usage: 635.6+ KB

# %%
#train = train.astype(float)
#For numerical version

# %%
#train.info()

# %% [markdown]
# Look at the head of our data, make sure its good to go

# %%
train.head()
# Out:
#                      investor   commit  deal_size  invite  rating int_rate  \
# 3508      Ipanema Investments  Decline        500      90       2   Market
# 6455  Beef and Broccoli Union   Commit        600      80       1   Market
# 6915  Beef and Broccoli Union   Commit       1300     190       3    Below
# 6415          Cold Cut Credit  Decline       1000     110       6   Market
# 1766  Damiba Investment Group   Commit       1500     190       7   Market
#
#       covenants  total_fees  fee_share  prior_tier  invite_tier tier_change  \
# 3508          2          33        3.0  Bookrunner   Bookrunner        None
# 6455          2          31        5.5  Bookrunner   Bookrunner        None
# 6915          3         218        3.9  Bookrunner   Bookrunner        None
# 6415          1          75        4.3  Bookrunner  Participant     Demoted
# 1766          0         171       33.7  Bookrunner   Bookrunner        None
#
#       fee_percent  invite_percent
# ...

# %%
print('Train has {} files and {} columns'.format(test.shape[0], test.shape[1]))
# Out:
# Train has 1809 files and 14 columns

# %%
test.head(100
         )
# Out:
#                      investor   commit  deal_size  invite  rating int_rate  \
# 5651  Bank of Pepperoni Pizza   Commit        800     110       2    Above
# 5504  Bank of Pepperoni Pizza   Commit       1600     300       5   Market
# 2694  Bank of Pepperoni Pizza   Commit       1500     170       7   Market
# 1294  Bank of Pepperoni Pizza   Commit       1400     240       4    Below
# 7149          Cold Cut Credit   Commit        600     100       2   Market
# 4379  Bank of Pepperoni Pizza   Commit       1200     240       5    Above
# 533   Beef and Broccoli Union   Commit       1500     350       7   Market
# 6836          Cold Cut Credit  Decline       1200     200       6   Market
# 1029  Beef and Broccoli Union   Commit        500      90       3   Market
# 4861  Damiba Investment Group   Commit       1400     250       5   Market
# 3850      Ipanema Investments   Commit       1500     200       9    Below
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1809 entries, 5651 to 725
# Data columns (total 14 columns):
# investor          1809 non-null object
# commit            1809 non-null object
# deal_size         1809 non-null int64
# invite            1809 non-null int64
# rating            1809 non-null int64
# int_rate          1809 non-null object
# covenants         1809 non-null int64
# total_fees        1809 non-null int64
# fee_share         1809 non-null float64
# prior_tier        1809 non-null object
# invite_tier       1809 non-null object
# tier_change       1809 non-null object
# fee_percent       1809 non-null float64
# invite_percent    1809 non-null float64
# dtypes: float64(3), int64(5), object(6)
# memory usage: 212.0+ KB

# %%
df =test.head()

# %% [markdown]
# To know how many different int values are for each column

# %%
train.select_dtypes(int).nunique()
# Out:
# deal_size      25
# invite         54
# rating         10
# covenants       4
# total_fees    301
# dtype: int64

# %%
test.select_dtypes(int).nunique()
# Out:
# deal_size      25
# invite         45
# rating         10
# covenants       4
# total_fees    278
# dtype: int64

# %% [markdown]
# **Clean Data**
# Wrangle, prepare, cleanse the data
# Detecting null values on each column

# %%
print('Empty values by column in Train ', (train.isnull().sum()))
# Out:
# Empty values by column in Train  investor          0
# commit            0
# deal_size         0
# invite            0
# rating            0
# int_rate          0
# covenants         0
# total_fees        0
# fee_share         0
# prior_tier        0
# invite_tier       0
# tier_change       0
# fee_percent       0
# invite_percent    0
# dtype: int64

# %%
print('Empty values by column in Test ',(test.isnull().sum()))
# Out:
# Empty values by column in Test  investor          0
# commit            0
# deal_size         0
# invite            0
# rating            0
# int_rate          0
# covenants         0
# total_fees        0
# fee_share         0
# prior_tier        0
# invite_tier       0
# tier_change       0
# fee_percent       0
# invite_percent    0
# dtype: int64

# %% [markdown]
# Working with Title and Name columns to fill out Age Nan values

# %% [markdown]
# Mapping str values to convert into float

# %%
mapping = {'Commit':1, 'Decline':-1}
train['commit'] = train['commit'].replace(mapping).astype(np.float64)
test['commit'] = test['commit'].replace(mapping).astype(np.float64)

# %%
mapping2 = {'Above':1, 'Below':-1, 'Market': 0}
train['int_rate'] = train['int_rate'].replace(mapping2).astype(np.float64)
test['int_rate'] = test['int_rate'].replace(mapping2).astype(np.float64)

# %%
mapping3 = {'Bookrunner':1, 'Participant':-1}
train['prior_tier'] = train['prior_tier'].replace(mapping3).astype(np.float64)
test['prior_tier'] = test['prior_tier'].replace(mapping3).astype(np.float64)
train['invite_tier'] = train['invite_tier'].replace(mapping3).astype(np.float64)
test['invite_tier'] = test['invite_tier'].replace(mapping3).astype(np.float64)

# %%
mapping4 = {'None':0, 'Promoted':1, 'Demoted': -1}
train['tier_change'] = train['tier_change'].replace(mapping4).astype(np.float64)
test['tier_change'] = test['tier_change'].replace(mapping4).astype(np.float64)

# %%
train.head()
# Out:
#                      investor  commit  deal_size  invite  rating  int_rate  \
# 3508      Ipanema Investments    -1.0        500      90       2       0.0
# 6455  Beef and Broccoli Union     1.0        600      80       1       0.0
# 6915  Beef and Broccoli Union     1.0       1300     190       3      -1.0
# 6415          Cold Cut Credit    -1.0       1000     110       6       0.0
# 1766  Damiba Investment Group     1.0       1500     190       7       0.0
#
#       covenants  total_fees  fee_share  prior_tier  invite_tier  tier_change  \
# 3508          2          33        3.0         1.0          1.0          0.0
# 6455          2          31        5.5         1.0          1.0          0.0
# 6915          3         218        3.9         1.0          1.0          0.0
# 6415          1          75        4.3         1.0         -1.0         -1.0
# 1766          0         171       33.7         1.0          1.0          0.0
#
#       fee_percent  invite_percent
# ...

# %% [markdown]
# Detect outliers

# %% [markdown]
# **Plotting**

# %% [markdown]
# To determine if Fare influence in Survival rate

# %%
plt.figure(figsize=[16,18])
plt.subplot(234)
plt.hist(x = [train[train['commit']==1]['invite_tier'], train[train['commit']==-1]['invite_tier']], 
         stacked=True, color = ['g', 'r'],label = ['Commit','Decline'])
plt.title('Invite Tier Impact on Commit/Decline')
plt.xlabel('Invite Tier(-1=Participant, -2=Bookrunner)')
plt.ylabel('Total Offers Tendered')
plt.legend();
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/core/fromnumeric.py:52: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %% [markdown]
# Barplot to determine Survival by Class

# %%
sns.barplot(x="prior_tier", y="commit", data=train)
plt.ylabel("")
plt.title("Distribution of Commits by Prior Tier")
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:1428: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data)

# %% [markdown]
# **Correlation**

# %%
train.corr()
# Out:
#                   commit  deal_size    invite    rating  int_rate  covenants  \
# commit          1.000000   0.128219  0.336445  0.050683  0.084172   0.003535
# deal_size       0.128219   1.000000  0.828095  0.499924 -0.000234  -0.452591
# invite          0.336445   0.828095  1.000000  0.403035 -0.000558  -0.367857
# rating          0.050683   0.499924  0.403035  1.000000  0.012772  -0.820791
# int_rate        0.084172  -0.000234 -0.000558  0.012772  1.000000  -0.003757
# covenants       0.003535  -0.452591 -0.367857 -0.820791 -0.003757   1.000000
# total_fees      0.205366   0.664000  0.559166  0.355662  0.022325  -0.111762
# fee_share       0.231361   0.429357  0.473782  0.241396  0.019902  -0.082156
# prior_tier     -0.185800  -0.003776 -0.005028  0.027876  0.018170  -0.021738
# invite_tier     0.607319  -0.010523  0.361549 -0.023741  0.002139   0.012054
# tier_change     0.575441  -0.005328  0.272505 -0.036173 -0.010465   0.023399
# ...

# %%
def correlation_heat(df):
    _ , ax = plt.subplots(figsize =(14, 12))
    colormap = sns.diverging_palette(220, 10, as_cmap = True)
    
    _ = sns.heatmap(
        df.corr(), 
        cmap = colormap,
        square=True, 
        cbar_kws={'shrink':.9 }, 
        ax=ax,
        annot=True, 
        linewidths=0.1,vmax=1.0, linecolor='white',
        annot_kws={'fontsize':12 }
    )
    
    plt.title('Pearson Correlation of Features', y=1.05, size=15)

# %%
correlation_heat(train[["commit", "deal_size", "invite", "rating", 
                        "int_rate", "covenants" ,"total_fees", "prior_tier", 
                        "invite_tier", "tier_change"
]])

# %%
correlation_heat(train[["commit", "invite_tier", "tier_change"]])

# %%
Pierre Damiba

# %%
# !pip install seaborn

# %%
import seaborn as sns

# %%
current_palette = sns.color_palette()
sns.set_palette(sns.diverging_palette(12, 133, l=40, n=2))

# %%
sns.pairplot(train, hue='commit', palette='husl')

# %%
sns.palplot(sns.diverging_palette(133, 12, l=40, n=2))

# %% [markdown]
# **Splitting data**

# %%
#FAST FOOD MODEL

#Not much substance, but in a fix they do the trick.

# %%
features = ["deal_size", "invite", "rating", 
                        "int_rate", "covenants" ,"total_fees", "prior_tier", 
                        "invite_tier", "tier_change"]
#Columns to wrok with in Train
X_train = train[features] #define training features set
y_train = train["commit"] 
#Columns to work with in Test
X_test = test[features] #define testing features set

# %% [markdown]
# Infer missing data from known data

# %% [markdown]
# to create validation data set

# %%
from sklearn.model_selection import train_test_split 
X_training, X_valid, y_training, y_valid = train_test_split(X_train, y_train, test_size=0.2, random_state=0)

# %% [markdown]
# **Score data**

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import f1_score, make_scorer
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# **Supervised Learning Estimators
# **
# Here we are detecting wich is the best model to predict Commit/Decline

# %%
from sklearn.svm import LinearSVC
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import LogisticRegressionCV, RidgeClassifierCV
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis
from sklearn.neighbors import KNeighborsClassifier
import warnings 
from sklearn.exceptions import ConvergenceWarning
from sklearn.metrics import f1_score, make_scorer

scorer = make_scorer(f1_score, greater_is_better=True, average = 'macro')

warnings.filterwarnings('ignore', category = ConvergenceWarning)
warnings.filterwarnings('ignore', category = DeprecationWarning)
warnings.filterwarnings('ignore', category = UserWarning)

# %% [markdown]
# Create a function to stock results of each model

# %%
model_results = pd.DataFrame(columns = ['model', 'cv_mean', 'cv_std'])

def cv_model(X_train, y_train, model, name, model_results = None, sort = True):
    #10 fold cross validation model##
    cv_scores = cross_val_score(model, X_train, y_train, cv = 10,
                                scoring = scorer, n_jobs = -1)
    print('Mean ', round(cv_scores.mean(), 5),'STd', round(cv_scores.std(), 5))
    if model_results is not None:
        model_results = model_results.append(pd.DataFrame({'model':name,
                                                'cv_mean': cv_scores.mean(),
                                                'cv_std' : cv_scores.std()},
                                                index = [0]), ignore_index = True)
    return model_results

model_results = cv_model(X_train, y_train, LinearSVC(), 'LSVC', 
                         model_results)

model_results = cv_model(X_train, y_train, 
                         GaussianNB(), 'GNB', model_results)

model_results = cv_model(X_train, y_train, 
                         MLPClassifier(hidden_layer_sizes=(16, 32, 64, 64, 32)),
                         'MLP', model_results)

model_results = cv_model(X_train, y_train, 
                          LinearDiscriminantAnalysis(), 
                          'LDA', model_results)

model_results = cv_model(X_train, y_train, 
                         RidgeClassifierCV(), 'RIDGE', model_results)

for n in [5, 10, 20]:
    print('\nKNN with {n} neighbors\n', n)
    model_results = cv_model(X_train, y_train, 
                             KNeighborsClassifier(n_neighbors = n),
                             n, model_results)
    
from sklearn.ensemble import ExtraTreesClassifier

model_results = cv_model(X_train, y_train, 
                         ExtraTreesClassifier(n_estimators = 100, random_state = 10),
                         'EXT', model_results)

model_results = cv_model(X_train, y_train,
                          RandomForestClassifier(100, random_state=10),
                              'RF', model_results)
from xgboost import XGBClassifier
model_results = cv_model(X_train, y_train,
                          XGBClassifier(n_estimators= 100, random_state=10),
                              'XGB', model_results)

model_results.set_index('model', inplace = True)
# Out:
# Mean  0.70352 STd 0.1901
# Mean  0.829 STd 0.01915
# Mean  0.70685 STd 0.08305
# Mean  0.81629 STd 0.02305
# Mean  0.82005 STd 0.02267
#
# KNN with {n} neighbors
#  5
# Mean  0.76241 STd 0.02099
#
# KNN with {n} neighbors
#  10
# Mean  0.77215 STd 0.01978
#
# KNN with {n} neighbors
#  20
# Mean  0.76697 STd 0.02848
# Mean  0.78503 STd 0.02082
# Mean  0.79805 STd 0.02902
# Mean  0.82692 STd 0.01653

# %%
print(model_results)
# Out:
#         cv_mean    cv_std
# model
# LSVC   0.703518  0.190099
# GNB    0.828999  0.019153
# MLP    0.706848  0.083054
# LDA    0.816290  0.023049
# RIDGE  0.820049  0.022669
# 5      0.762412  0.020995
# 10     0.772149  0.019782
# 20     0.766967  0.028484
# EXT    0.785033  0.020818
# RF     0.798054  0.029019
# XGB    0.826915  0.016532

# %%
model_results['cv_mean'].plot.bar(color = 'orange', figsize = (8, 6),
                                  yerr = list(model_results['cv_std']))
plt.title('Model F1 Score Results');
plt.ylabel('Mean F1 Score (with error bar)');
model_results.reset_index(inplace = True)

# %% [markdown]
# **Predict most accuracy output XGBoost **

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer, accuracy_score 

xg_clf = XGBClassifier()
parameters_rf = {'n_estimators' : [200],'learning_rate': [0.1],
              'max_depth': [4], "min_child_weight":[6], "gamma":[0], "subsample":[0.80] 
                              }


grid_rf = GridSearchCV(xg_clf, parameters_rf, scoring=make_scorer(accuracy_score))
#make_scorer(accuracy_score)
grid_rf.fit(X_training, y_training)
xg_clf = grid_rf.best_estimator_

pred_xg = xg_clf.predict(X_valid)
acc_xg = accuracy_score(y_valid, pred_xg)
print("The Score for XGBoost is: " + str(acc_xg))
print("The best Score for XGBoost is: " + str(grid_rf.best_score_))
# Out:
# The Score for XGBoost is: 0.8866359447004608
# The best Score for XGBoost is: 0.8930629177229776

# %% [markdown]
#  **Predict most accuracy output RandomForest Classifier **

# %%
rf_clf = RandomForestClassifier()

parameters_rf = {"n_estimators": [4, 5, 6, 7, 8, 9, 10, 15], "criterion": ["gini", "entropy"], "max_features": ["auto", "sqrt", "log2"], 
                 "max_depth": [2, 3, 5, 10], "min_samples_split": [2, 3, 5, 10]}

grid_rf = GridSearchCV(rf_clf, parameters_rf, scoring=make_scorer(accuracy_score))
grid_rf.fit(X_training, y_training)

rf_clf = grid_rf.best_estimator_

rf_clf.fit(X_training, y_training)
pred_rf = rf_clf.predict(X_valid)
acc_rf = accuracy_score(y_valid, pred_rf)

print("The Score for Random Forest is: " + str(acc_rf))

print("The best Score for Random Forest is: " + str(grid_rf.best_score_))

# %% [markdown]
# Export a submission file with the predictions of test Dataset
