# %% [markdown]
# <a href="https://colab.research.google.com/github/pierretd/investor-classifier/blob/master/TakingaLook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Importing data

# %%
from sklearn.model_selection import train_test_split
train, test = train_test_split(pd.read_csv('https://raw.githubusercontent.com/pierretd/investor-classifier/master/data/fake_data%20-%20investor_data_2.csv'), random_state=0)
data = train.append(test)

# %%
print('Train has {} rows and {} columns.'.format(train.shape[0], train.shape[1]))
# Out:
# Train has 5424 rows and 14 columns.

# %% [markdown]
# To know the total of columns

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5424 entries, 3508 to 2732
# Data columns (total 14 columns):
# investor          5424 non-null object
# commit            5424 non-null object
# deal_size         5424 non-null int64
# invite            5424 non-null int64
# rating            5424 non-null int64
# int_rate          5424 non-null object
# covenants         5424 non-null int64
# total_fees        5424 non-null int64
# fee_share         5424 non-null float64
# prior_tier        5424 non-null object
# invite_tier       5424 non-null object
# tier_change       5424 non-null object
# fee_percent       5424 non-null float64
# invite_percent    5424 non-null float64
# dtypes: float64(3), int64(5), object(6)
# memory usage: 635.6+ KB

# %%
#train = train.astype(float)
#For numerical version

# %%
#Start as structured image and  then if you had a predictive model that predicted the price of the structured data and then use somethng that classify that images Condition of the card on vision

#Bokeh

#We are legion we are bob

#Thrawn

# %%
#train.info()

# %% [markdown]
# Look at the head of our data, make sure its good to go

# %%
train.head()
# Out:
#                      investor   commit  deal_size  invite  rating int_rate  \
# 3508      Ipanema Investments  Decline        500      90       2   Market
# 6455  Beef and Broccoli Union   Commit        600      80       1   Market
# 6915  Beef and Broccoli Union   Commit       1300     190       3    Below
# 6415          Cold Cut Credit  Decline       1000     110       6   Market
# 1766  Damiba Investment Group   Commit       1500     190       7   Market
#
#       covenants  total_fees  fee_share  prior_tier  invite_tier tier_change  \
# 3508          2          33        3.0  Bookrunner   Bookrunner        None
# 6455          2          31        5.5  Bookrunner   Bookrunner        None
# 6915          3         218        3.9  Bookrunner   Bookrunner        None
# 6415          1          75        4.3  Bookrunner  Participant     Demoted
# 1766          0         171       33.7  Bookrunner   Bookrunner        None
#
#       fee_percent  invite_percent
# ...

# %%
print('Train has {} files and {} columns'.format(test.shape[0], test.shape[1]))
# Out:
# Train has 1809 files and 14 columns

# %%
test.head(100
         )
# Out:
#                      investor   commit  deal_size  invite  rating int_rate  \
# 5651  Bank of Pepperoni Pizza   Commit        800     110       2    Above
# 5504  Bank of Pepperoni Pizza   Commit       1600     300       5   Market
# 2694  Bank of Pepperoni Pizza   Commit       1500     170       7   Market
# 1294  Bank of Pepperoni Pizza   Commit       1400     240       4    Below
# 7149          Cold Cut Credit   Commit        600     100       2   Market
# 4379  Bank of Pepperoni Pizza   Commit       1200     240       5    Above
# 533   Beef and Broccoli Union   Commit       1500     350       7   Market
# 6836          Cold Cut Credit  Decline       1200     200       6   Market
# 1029  Beef and Broccoli Union   Commit        500      90       3   Market
# 4861  Damiba Investment Group   Commit       1400     250       5   Market
# 3850      Ipanema Investments   Commit       1500     200       9    Below
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1809 entries, 5651 to 725
# Data columns (total 14 columns):
# investor          1809 non-null object
# commit            1809 non-null object
# deal_size         1809 non-null int64
# invite            1809 non-null int64
# rating            1809 non-null int64
# int_rate          1809 non-null object
# covenants         1809 non-null int64
# total_fees        1809 non-null int64
# fee_share         1809 non-null float64
# prior_tier        1809 non-null object
# invite_tier       1809 non-null object
# tier_change       1809 non-null object
# fee_percent       1809 non-null float64
# invite_percent    1809 non-null float64
# dtypes: float64(3), int64(5), object(6)
# memory usage: 212.0+ KB

# %%
df =test.head()

# %% [markdown]
# To know how many different int values are for each column

# %%
train.select_dtypes(int).nunique()
# Out:
# deal_size      25
# invite         54
# rating         10
# covenants       4
# total_fees    301
# dtype: int64

# %%
test.select_dtypes(int).nunique()
# Out:
# deal_size      25
# invite         45
# rating         10
# covenants       4
# total_fees    278
# dtype: int64

# %% [markdown]
# **Clean Data**
# Wrangle, prepare, cleanse the data
# Detecting null values on each column

# %%
print('Empty values by column in Train ', (train.isnull().sum()))
# Out:
# Empty values by column in Train  investor          0
# commit            0
# deal_size         0
# invite            0
# rating            0
# int_rate          0
# covenants         0
# total_fees        0
# fee_share         0
# prior_tier        0
# invite_tier       0
# tier_change       0
# fee_percent       0
# invite_percent    0
# dtype: int64

# %%
print('Empty values by column in Test ',(test.isnull().sum()))
# Out:
# Empty values by column in Test  investor          0
# commit            0
# deal_size         0
# invite            0
# rating            0
# int_rate          0
# covenants         0
# total_fees        0
# fee_share         0
# prior_tier        0
# invite_tier       0
# tier_change       0
# fee_percent       0
# invite_percent    0
# dtype: int64
